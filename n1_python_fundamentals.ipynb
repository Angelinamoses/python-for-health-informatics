# %% [markdown]
# ## Title
#
# ### Python Fundamentals for Health Informatics

# %% [markdown]
# ## Goal of this notebook
#
# By the end of this notebook, you should be able to:
#
#     understand what Python is,
#     run your first Python code,
#     use comments and print statements,
#     work with variables and basic data types,
#     understand simple input and output,
#     connect basic Python ideas to health informatics,
#     solve beginner case-based exercises.

# %% [markdown]
# ## What is Python?
#
# Python is a programming language used to give instructions to a computer.
# You can use Python to:
#
#   * store and process data,
#   * automate repetitive tasks,
#   * build tools and applications,
#   * analyze health data,
#   * support reporting and decision-making in healthcare.

# %% [markdown]
# ## Why Python matters in Health Informatics
#
# Health informatics deals with health data, systems, and workflows. Python can help with tasks like:
#
# * managing patient records,
# * checking data quality,
# * analyzing lab results,
# * automating reports,
# * creating simple clinical tools.

# %% [markdown]
# ## Simple idea
#
# If health data is a giant mess of information, Python is one of the tools that helps you clean, organize, and understand it. Humanity loves spreadsheets until the spreadsheet bites back.

# %%
# Your first python code:
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## What it does is;
# * print() tells python to show something on the screen.
# * The text inside quotes is called a string
# ## Health Informatics example
#  *print("Welcome to the patient data system")
# this could represent a simple message in a hospital software tool

# %% [markdown]
# ## Comments in Python
# comments are notes for humans. Python ignores them.

# %%
# This is a comment
print("python is running")
# Out:
# python is running

# %% [markdown]
# ## Why comments matter?
# In health informatics projects, comments help explain:
#  * Why a calculation is dome,
#  * What a function is supposed to do,
#  * Why a specific rule exists.

# %% [markdown]
# ## Variables
# A variable stores a value.

# %%
### Think of it like a labeled box.
patient_name = "Angelina"
age = 22

# %% [markdown]
# ## What is happening?
#  * patient_name stores the name.
#  * age stores the number 22

# %% [markdown]
# ### Rules for Variable names:
#  * Use letters, numbers and underscores,
#  * do not start with a number,
#  * avoid spaces,
#  * choose meaningful names.

# %%
#Good examples:
patient_id = 102
blood_pressure = 120

# %% [markdown]
# ## Health Informatics relevance
# Variables are used to store:
# * Patient age,
# * test Values,
# * Appointment dates,
# * Symptom counts,
# * Hospital ward numbers.

# %% [markdown]
# ## Basic data types
# Python has different types of data.

# %%
#String; Text data.
hospital_name = "Apollo"

#Integer; Whole numbers.
patient_age = 30

#Float; Decimal numbers.
height = 165.5

#Boolean; True or False
has_fever = True

# %% [markdown]
# ## Why types matter in Health Informatics
# Different health data must be handled correctly:
#  * Patient names are text,
#  * age is a number,
#  * Temperature may have decimals,
#  * A condition like diabetic or not is often true/false.

# %% [markdown]
# ## Using type()

# %%
# type() tell you what kind of data a value is.
print(type("Hello"))
print(type(25))
print(type(98.9))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Why this is useful
# In healthcare data, the wrong data type can cause errors.
# For example,
#   * age should be a number, not text.
#   * age = "twenty"
#   * this is not useful if you want to calculate age-based risk.

# %% [markdown]
# ## Basic input from the user:
# You can ask the user to enter information

# %%
name = input("Enter patient name: ")
print("patient name is", name)
# Out:
# Enter patient name:  Asha
# patient name is Asha

# %% [markdown]
# ## Important detail
# input() always gives text

# %%
age = input("Enter age: ")
print(type(age))
# Out:
# Enter age:  22
# <class 'str'>

# %% [markdown]
# ## Health informatics example
# A patient intake form may ask for:
# * name,
# * age,
# * symptoms,
# * Contact number.

# %% [markdown]
# ## Type Conversion
# Sometimes you need to convert text into a number.

# %%
age = int(input("Enter age: "))
print(age + 1)
# Out:
# Enter age:  22
# 23

# %% [markdown]
# ## Why this matters
# If age is stored as text, you cannot do math with it.

# %% [markdown]
# ## Simple Calculations
# Python can do math.

# %%
weight = 22
height = 1.17
bmi = weight/(height**2)
print(bmi)
# Out:
# 16.071298122580178

# %% [markdown]
# ## Health informatics relevance
# Simple calculations are used in:
#  * BMI,
#  * Dosage checks,
#  * risk scoring,
#  * averages,
#  * trend analysis.

# %% [markdown]
# ## Patient greeting

# %%
#Patient greeting
patient_name = input("enter patient name: ")
print("Hello,", patient_name)
# Out:
# enter patient name:  Asha
# Hello, Asha

# %% [markdown]
# ## Age Check

# %%
age = int(input("Enter age: "))
print("Age entered:", age)
# Out:
# Enter age:  25
# Age entered: 25

# %% [markdown]
# ## BMI starter

# %%
weight = float(input("Enter weight in kg: "))
height = float(input("Enter height in meters: "))
bmi = weight/(height**2)
print("BMI: ", bmi)
# Out:
# Enter weight in kg:  67
# Enter height in meters:  1.75
# BMI:  21.877551020408163

# %% [markdown]
# ## Concept Summary
# What you learned:
#  * Python is a language for instructing computers.
#  * print() shows output.
#  * Comments are for humans.
#  * Variables store data.
#  * Data types matters.
#  * input() collects user input.
#  * type() checks data type.
#  * Type conversion helps with calculations.
#  * Basic math can support health informatics tasks

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### print your name
# Write Python code to print your name.

# %% [markdown]
# ### Store patient details
# Create variables for:
#  * patient name,
#  * age,
#  * hospital name, print them.

# %% [markdown]
# ### Check data types
# Create one string, one integer, one float, and one boolean. Use type() on each.

# %% [markdown]
# ### Ask for input
# Ask the user for their favourite health topic and print it.

# %% [markdown]
# ## Health Informatics case-based problems

# %% [markdown]
# ### Outpatient registration
# A clinic wants a simple program to collect a patient's name and age.
# Task:
#  * Ask for name,
#  * Ask for age,
#  * print a welcome message.

# %% [markdown]
# ### Basic age Validation
# A hospital from needs the patient's age as anumber.
# Task:
#  * Ask for age,
#  * Convert it to an integer,
#  * print the age increased by 1.
#
# Why this matters: Age is often used in eligibility checks and risk rules.

# %% [markdown]
# ### BMI calculator starter
# A wellness app wants to calculate BMI.
# Tasks:
#  * Ask for weight in kg,
#  * Ask for height in meters,
#  * Calculate BMI,
#  * print the result.

# %% [markdown]
# ### Basic patient flag
# A doctor wants to know whether a patient has fever.
# Task:
# * Create a variable called has_fever and set it to True or False.
# * print the value.
# * Health Informatics idea: Flags like this are used in triage and screening syatems.
