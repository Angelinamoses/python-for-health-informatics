# %% [markdown]
# ### classes_objects
#
# ### classes and objects: Modeling Real Healthcare Entities
#
# ### Why OOP Exists?
# _imagine storing patient information_

# %%
# without classes:

patient_name = "Asha"
patient_age = 24
patient_id = "P001"

# %% [markdown]
# Now imagive 10,000 patients.
#
# chaos right? we need a structure.
#
# _classes provide templates._
#
# and objects are actual instances created from those templates.

# %%
class Patient:  # Define a class named Patient        
    pass

# %% [markdown]
# This class currently does nothing.
#
# _but python now knows what a patient is._

# %%
patient1 = Patient()  # Create an instance of the Patient class

print(patient1)  # Output the instance to see its memory address

# %%
patient2 = Patient()  # Create another instance of the Patient class

print(patient2)  # Output the second instance to see its memory address

# %% [markdown]
# _Notice they are different objects_
#
# ### Health Informatics Relevance
#
# _example of classes_
#
# * Patient
# * Doctor
# * Appointment
# * LabResult
# * Medication
# * Hospital
# * InsuranceClaim
#
# _most healthcare software is built around objects_

# %%
# Exercise 1: Create a class named Doctor

class Doctor:
    pass

# %%
# Exercise: Create a class named Hospital

class Hospital:
    pass

# %% [markdown]
# ### attributes_methods
#
# ### Attributes and Methods: Giving Objects Data and Behavior
#
# _Attributes store information_
#
# patient has:
#
# * name
# * age
# * patient_id
# * blood_group
#
# _these are attributes_

# %%
class Patient:
    pass

# %%
patient = Patient()

patient.name = "Asha"
patient.age = 24
patient.id = "P001"

print(patient.name)  # Output: Asha
# Out:
# Asha

# %% [markdown]
# _attributes represent data_
#
# What are Methods?
#
# Example:
#
# * Patient checks in
# * Patient views report
# * Patient updates profile

# %%
class Patient:

    def display_info(self):
        print("patient information displayed")

# %%
patient = Patient()

patient.display_info()  # Output: patient information displayed
# Out:
# patient information displayed

# %% [markdown]
# 'self' refers to the current object.

# %%
class Patient:

    def greet(self):
        print("Hello Patient.")

# %%
patient = Patient()

patient.greet() # Output: Hello Patient.
# Out:
# Hello Patient.

# %%
# Health informatics example:

class Patient:

    def display_id(self):
        print("Patient ID displayed")

# %% [markdown]
# ### Exercises
#
# * Create Doctor class with name attribute.
# * Create Hospital class with location attribute
# * Add method called 'show_details()'

# %% [markdown]
# ### constructors
#
# ### Constructors: Initializing Objects Automatically
#
# Why Constructors?

# %%
# without constructor:

class Patient:

    pass

# %%
patient = Patient()

patient.name = "Asha"
patient.age = 24   # must set everything manually

# %%
# with constructor:
class Patient:

    def __init__(self, name, age):   #__init__ is the constructor method, runs automatically when an instance is created
        self.name = name
        self.age = age

# %%
# Health informatics example:

class LabResult:

    def __init__(self, test_name, result_value):
        self.test_name = test_name
        self.result_value = result_value

# %%
result_value = LabResult("Blood Glucose", 5.6)

print(result_value.test_name)  # Output: Blood Glucose
print(result_value.result_value)  # Output: 5.6
# Out:
# Blood Glucose
# 5.6

# %% [markdown]
# ### Exercises:
#
# * create appointment constructor.
# * create doctor costructor
# * create medication constructor

# %% [markdown]
# ### inheritance
#
# ### Inheritance: Reusing Existing Code
#
# Why Inheritance?
# _Doctor and Patient share common properties, instead of rewriting it_
#
# Reuse it.

# %%
class Person:

    def greet(self):
        print("Hello!")

# %%
class Patient(Person):  # Patient class inherits from Person class
    pass

# %%
patient = Patient()

patient.greet()  # Output: Hello!
# Out:
# Hello!

# %%
class Doctor(Person):  # Doctor class also inherits from Person class
    
    def prescribe(self):
        print("Medication prescribed.")

# %%
doctor = Doctor()

doctor.greet()  # Output: Hello!
doctor.prescribe()  # Output: Medication prescribed.
# Out:
# Hello!
# Medication prescribed.

# %% [markdown]
# ### Exercises:
#
# * create employee parent class
# * create doctor child class
# * create nurse child class

# %% [markdown]
# ### polymorphism
#
# ### Polymorphism: One Interface, Many Forms
#
# What is Polymorphism?
# _same method, but different behaviour_
